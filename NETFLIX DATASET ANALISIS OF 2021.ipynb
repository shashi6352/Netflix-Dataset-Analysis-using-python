# %% [markdown]
# # NETFLIX DATASET
#
# This dataset consists of tv shows and movies available on Netflix as of 2019. The dataset is collected from Flixable which is a third-party Netflix search engine.

# %%
import pandas as pd #import libraries

# %%
data=pd.read_csv(r"C:\Users\Shashi Shekhar\Desktop\python\Dataset for resume projects\NetFlix.csv")
data
# Out:
#      show_id     type                                      title  \
# 0         s1  TV Show                                         3%
# 1        s10    Movie                                       1920
# 2       s100    Movie                                 3 Heroines
# 3      s1000    Movie  Blue Mountain State: The Rise of Thadland
# 4      s1001  TV Show                             Blue Planet II
# ...      ...      ...                                        ...
# 7782    s995  TV Show                                 Blown Away
# 7783    s996  TV Show                              Blue Exorcist
# 7784    s997    Movie                  Blue Is the Warmest Color
# 7785    s998    Movie                               Blue Jasmine
# 7786    s999    Movie                                   Blue Jay
#
#                  director                                               cast  \
# 0                     NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %% [markdown]
# # Data Explanatory
# ### 1 .head()

# %%
data.head()
# Out:
#   show_id     type                                      title        director  \
# 0      s1  TV Show                                         3%             NaN
# 1     s10    Movie                                       1920    Vikram Bhatt
# 2    s100    Movie                                 3 Heroines  Iman Brotoseno
# 3   s1000    Movie  Blue Mountain State: The Rise of Thadland    Lev L. Spiro
# 4   s1001  TV Show                             Blue Planet II             NaN
#
#                                                 cast         country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...          Brazil
# 1  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...           India
# 2  Reza Rahadian, Bunga Citra Lestari, Tara Basro...       Indonesia
# 3  Alan Ritchson, Darin Brooks, James Cade, Rob R...   United States
# 4                                 David Attenborough  United Kingdom
#
#   date_added  release_year rating  duration  \
# ...

# %% [markdown]
# ### 2 .tail()

# %%
data.tail()
# Out:
#      show_id     type                      title             director  \
# 7782    s995  TV Show                 Blown Away                  NaN
# 7783    s996  TV Show              Blue Exorcist                  NaN
# 7784    s997    Movie  Blue Is the Warmest Color  Abdellatif Kechiche
# 7785    s998    Movie               Blue Jasmine          Woody Allen
# 7786    s999    Movie                   Blue Jay         Alex Lehmann
#
#                                                    cast  \
# 7782                                                NaN
# 7783  Nobuhiko Okamoto, Jun Fukuyama, Kana Hanazawa,...
# 7784  Léa Seydoux, Adèle Exarchopoulos, Salim Kechio...
# 7785  Cate Blanchett, Sally Hawkins, Alec Baldwin, L...
# 7786           Sarah Paulson, Mark Duplass, Clu Gulager
#
#                      country date_added  release_year rating  duration  \
# 7782                  Canada  12-Jul-19          2019  TV-14         1
# ...

# %% [markdown]
# ### 3 .shape

# %%
data.shape
# Out:
# (7787, 12)

# %% [markdown]
# ### 4. size

# %%
data.size ##to show total number of elements in dataset
# Out:
# 93444

# %% [markdown]
# ### 5 .columns

# %%
data.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'genres', 'description'],
#       dtype='object')

# %% [markdown]
# ### 6 .dtypes

# %%
data.dtypes #getting datatype of each column
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration         int64
# genres          object
# description     object
# dtype: object

# %% [markdown]
# ### 7 .info()

# %%
data.info() #getting complete information about dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7787 entries, 0 to 7786
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7787 non-null   object
#  1   type          7787 non-null   object
#  2   title         7787 non-null   object
#  3   director      5398 non-null   object
#  4   cast          7069 non-null   object
#  5   country       7280 non-null   object
#  6   date_added    7777 non-null   object
#  7   release_year  7787 non-null   int64
#  8   rating        7780 non-null   object
#  9   duration      7787 non-null   int64
#  10  genres        7787 non-null   object
#  11  description   7787 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 730.2+ KB

# %% [markdown]
# ### Task 1. Is there any duplicate records in your dataset? if yes then remove the duplicate records

# %%
data.head()
# Out:
#   show_id     type                                      title        director  \
# 0      s1  TV Show                                         3%             NaN
# 1     s10    Movie                                       1920    Vikram Bhatt
# 2    s100    Movie                                 3 Heroines  Iman Brotoseno
# 3   s1000    Movie  Blue Mountain State: The Rise of Thadland    Lev L. Spiro
# 4   s1001  TV Show                             Blue Planet II             NaN
#
#                                                 cast         country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...          Brazil
# 1  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...           India
# 2  Reza Rahadian, Bunga Citra Lestari, Tara Basro...       Indonesia
# 3  Alan Ritchson, Darin Brooks, James Cade, Rob R...   United States
# 4                                 David Attenborough  United Kingdom
#
#   date_added  release_year rating  duration  \
# ...

# %%
data.shape
# Out:
# (7787, 12)

# %%
data.duplicated()#getting in boolean type result
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7782    False
# 7783    False
# 7784    False
# 7785    False
# 7786    False
# Length: 7787, dtype: bool

# %%
data[data.duplicated()]#getting the duplicate records
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, genres, description]
# Index: []

# %%
data.drop_duplicates(inplace=True) #removing duplicates records and for permanently use "inplace=True"

# %%
data.shape
# Out:
# (7787, 12)

# %% [markdown]
# ### Task 2. Is there any NULL value present in any column? show with heat map

# %%
data.head()
# Out:
#   show_id     type                                      title        director  \
# 0      s1  TV Show                                         3%             NaN
# 1     s10    Movie                                       1920    Vikram Bhatt
# 2    s100    Movie                                 3 Heroines  Iman Brotoseno
# 3   s1000    Movie  Blue Mountain State: The Rise of Thadland    Lev L. Spiro
# 4   s1001  TV Show                             Blue Planet II             NaN
#
#                                                 cast         country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...          Brazil
# 1  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...           India
# 2  Reza Rahadian, Bunga Citra Lestari, Tara Basro...       Indonesia
# 3  Alan Ritchson, Darin Brooks, James Cade, Rob R...   United States
# 4                                 David Attenborough  United Kingdom
#
#   date_added  release_year rating  duration  \
# ...

# %%
data.isnull()#getting in boolean language
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False      True  False    False       False
# 1       False  False  False     False  False    False       False
# 2       False  False  False     False  False    False       False
# 3       False  False  False     False  False    False       False
# 4       False  False  False      True  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 7782    False  False  False      True   True    False       False
# 7783    False  False  False      True  False    False       False
# 7784    False  False  False     False  False    False       False
# 7785    False  False  False     False  False    False       False
# 7786    False  False  False     False  False    False       False
#
#       release_year  rating  duration  genres  description
# 0            False   False     False   False        False
# ...

# %%
data.isnull().sum() #getting the sum of NULL values
# Out:
# show_id            0
# type               0
# title              0
# director        2389
# cast             718
# country          507
# date_added        10
# release_year       0
# rating             7
# duration           0
# genres             0
# description        0
# dtype: int64

# %% [markdown]
#  ### for heatmap import seaborn library

# %%
import seaborn as sns

# %%
sns.heatmap(data.isnull()); #using heatmap to show null values

# %% [markdown]
# ## Question's part
# ### Q1. for "House of cards" what is the show id and who is the director of show?

# %%
#solve by using ".isin()"
data.head()
# Out:
#   show_id     type                                      title        director  \
# 0      s1  TV Show                                         3%             NaN
# 1     s10    Movie                                       1920    Vikram Bhatt
# 2    s100    Movie                                 3 Heroines  Iman Brotoseno
# 3   s1000    Movie  Blue Mountain State: The Rise of Thadland    Lev L. Spiro
# 4   s1001  TV Show                             Blue Planet II             NaN
#
#                                                 cast         country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...          Brazil
# 1  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...           India
# 2  Reza Rahadian, Bunga Citra Lestari, Tara Basro...       Indonesia
# 3  Alan Ritchson, Darin Brooks, James Cade, Rob R...   United States
# 4                                 David Attenborough  United Kingdom
#
#   date_added  release_year rating  duration  \
# ...

# %%
data["title"].isin(["House of Cards"]) #getting output in boolean language
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7782    False
# 7783    False
# 7784    False
# 7785    False
# 7786    False
# Name: title, Length: 7787, dtype: bool

# %%
data[data["title"].isin(["House of Cards"])] #getting the result
# Out:
#      show_id     type           title director  \
# 2038   s2833  TV Show  House of Cards      NaN
#
#                                                    cast        country  \
# 2038  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#      date_added  release_year rating  duration                   genres  \
# 2038  02-Nov-18          2018  TV-MA         6  TV Dramas, TV Thrillers
#
#                                             description
# 2038  A ruthless politician will stop at nothing to ...

# %%
#solve by using ".str.contains()"
data["title"].str.contains("House of Cards") #getting output in boolean language
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7782    False
# 7783    False
# 7784    False
# 7785    False
# 7786    False
# Name: title, Length: 7787, dtype: bool

# %%
data[data["title"].str.contains("House of Cards")] #getting the desired result
# Out:
#      show_id     type           title director  \
# 2038   s2833  TV Show  House of Cards      NaN
#
#                                                    cast        country  \
# 2038  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#      date_added  release_year rating  duration                   genres  \
# 2038  02-Nov-18          2018  TV-MA         6  TV Dramas, TV Thrillers
#
#                                             description
# 2038  A ruthless politician will stop at nothing to ...

# %% [markdown]
# ### Q2. Which year highest number of tv shows and movies get released? show with bar graph

# %%
# getting the information of datatype of date/year related columns
data.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration         int64
# genres          object
# description     object
# dtype: object

# %%
#convert "object" data type of column "date_added" to "datetime" data type by using command ".to_datetime()"
data["date_n"]=pd.to_datetime(data["date_added"])
# Out:
# C:\Users\Shashi Shekhar\AppData\Local\Temp\ipykernel_8716\1905347643.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data["date_n"]=pd.to_datetime(data["date_added"])

# %%
data.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added              object
# release_year             int64
# rating                  object
# duration                 int64
# genres                  object
# description             object
# date_n          datetime64[ns]
# dtype: object

# %%
#using command ".dt.year.value_counts()" to getting the year wise total/counts this filtering command by year
data["date_n"].dt.year.value_counts()
# Out:
# date_n
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: count, dtype: int64

# %%
#plotting bar graph by command ".plot(kind="bar")"
data["date_n"].dt.year.value_counts().plot(kind="bar");

# %% [markdown]
# ### Q3. how many tv show and movies in this dataset? show by bar graph

# %%
data.head()
# Out:
#   show_id     type                                      title        director  \
# 0      s1  TV Show                                         3%             NaN
# 1     s10    Movie                                       1920    Vikram Bhatt
# 2    s100    Movie                                 3 Heroines  Iman Brotoseno
# 3   s1000    Movie  Blue Mountain State: The Rise of Thadland    Lev L. Spiro
# 4   s1001  TV Show                             Blue Planet II             NaN
#
#                                                 cast         country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...          Brazil
# 1  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...           India
# 2  Reza Rahadian, Bunga Citra Lestari, Tara Basro...       Indonesia
# 3  Alan Ritchson, Darin Brooks, James Cade, Rob R...   United States
# 4                                 David Attenborough  United Kingdom
#
#   date_added  release_year rating  duration  \
# ...

# %%
data.groupby("type").type.count()#getting the result by using ".groupby()" and ".count()" of specific column
# Out:
# type
# Movie      5377
# TV Show    2410
# Name: type, dtype: int64

# %%
sns.countplot(data=data, x="type");

# %% [markdown]
# ### Q4. show all the movies released in year 2000

# %%
data.head()
# Out:
#   show_id     type                                      title        director  \
# 0      s1  TV Show                                         3%             NaN
# 1     s10    Movie                                       1920    Vikram Bhatt
# 2    s100    Movie                                 3 Heroines  Iman Brotoseno
# 3   s1000    Movie  Blue Mountain State: The Rise of Thadland    Lev L. Spiro
# 4   s1001  TV Show                             Blue Planet II             NaN
#
#                                                 cast         country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...          Brazil
# 1  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...           India
# 2  Reza Rahadian, Bunga Citra Lestari, Tara Basro...       Indonesia
# 3  Alan Ritchson, Darin Brooks, James Cade, Rob R...   United States
# 4                                 David Attenborough  United Kingdom
#
#   date_added  release_year rating  duration  \
# ...

# %%
#creating new coulumn by extracting only year from the date_n columns
data["year"]=data["date_n"].dt.year

# %%
data.head()
# Out:
#   show_id     type                                      title        director  \
# 0      s1  TV Show                                         3%             NaN
# 1     s10    Movie                                       1920    Vikram Bhatt
# 2    s100    Movie                                 3 Heroines  Iman Brotoseno
# 3   s1000    Movie  Blue Mountain State: The Rise of Thadland    Lev L. Spiro
# 4   s1001  TV Show                             Blue Planet II             NaN
#
#                                                 cast         country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...          Brazil
# 1  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...           India
# 2  Reza Rahadian, Bunga Citra Lestari, Tara Basro...       Indonesia
# 3  Alan Ritchson, Darin Brooks, James Cade, Rob R...   United States
# 4                                 David Attenborough  United Kingdom
#
#   date_added  release_year rating  duration  \
# ...

# %%
#filtering the data to get result
data[(data["type"]=="Movie") & (data["year"]==2000)]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, genres, description, date_n, year]
# Index: []

# %%
data[(data["type"]=="Movie") & (data["year"]==2020)]
# Out:
#      show_id   type                  title  \
# 20     s1016  Movie  Bobbleheads The Movie
# 22     s1018  Movie           Bobby Jasoos
# 28     s1023  Movie              Bodyguard
# 40     s1034  Movie         Bombay Talkies
# 62     s1054  Movie         Born Beautiful
# ...      ...    ...                    ...
# 7754     s97  Movie         3 Days to Kill
# 7757    s972  Movie                  Blaze
# 7762    s977  Movie         Bleed for This
# 7773    s987  Movie           Blood Father
# 7774    s988  Movie            Blood Money
#
#                                                director  \
# 20                                            Kirk Wise
# 22                                         Samar Shaikh
# 28                                             Siddique
# 40    Anurag Kashyap, Dibakar Banerjee, Karan Johar,...
# 62                                        Perci Intalan
# ...                                                 ...
# ...

# %% [markdown]
# ### Q5. show all the title of tv shows that were released in india

# %%
data.head()
# Out:
#   show_id     type                                      title        director  \
# 0      s1  TV Show                                         3%             NaN
# 1     s10    Movie                                       1920    Vikram Bhatt
# 2    s100    Movie                                 3 Heroines  Iman Brotoseno
# 3   s1000    Movie  Blue Mountain State: The Rise of Thadland    Lev L. Spiro
# 4   s1001  TV Show                             Blue Planet II             NaN
#
#                                                 cast         country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...          Brazil
# 1  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...           India
# 2  Reza Rahadian, Bunga Citra Lestari, Tara Basro...       Indonesia
# 3  Alan Ritchson, Darin Brooks, James Cade, Rob R...   United States
# 4                                 David Attenborough  United Kingdom
#
#   date_added  release_year rating  duration  \
# ...

# %%
#use filtering method to get the result
data[(data["type"]=="TV Show") & (data["country"]=="India")].title
# Out:
# 354                                      Chhota Bheem
# 368                                         7 (Seven)
# 421     ChuChu TV Nursery Rhymes & Kids Songs (Hindi)
# 461                                   Classic Legends
# 517                                   College Romance
#                             ...
# 7629                                           Betaal
# 7643                     21 Sarfarosh: Saragarhi 1897
# 7655                                      Bh Se Bhade
# 7656                               Bhaag Beanie Bhaag
# 7657                                   Bhaage Re Mann
# Name: title, Length: 71, dtype: object

# %% [markdown]
# ### Q6. show top 10 directors, who gave the highest number of tv shows and movies to netflix

# %%
data.head()
# Out:
#   show_id     type                                      title        director  \
# 0      s1  TV Show                                         3%             NaN
# 1     s10    Movie                                       1920    Vikram Bhatt
# 2    s100    Movie                                 3 Heroines  Iman Brotoseno
# 3   s1000    Movie  Blue Mountain State: The Rise of Thadland    Lev L. Spiro
# 4   s1001  TV Show                             Blue Planet II             NaN
#
#                                                 cast         country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...          Brazil
# 1  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...           India
# 2  Reza Rahadian, Bunga Citra Lestari, Tara Basro...       Indonesia
# 3  Alan Ritchson, Darin Brooks, James Cade, Rob R...   United States
# 4                                 David Attenborough  United Kingdom
#
#   date_added  release_year rating  duration  \
# ...

# %%
data["director"].value_counts().head(10) #getting the result
# Out:
# director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Youssef Chahine           12
# Martin Scorsese           12
# Jay Chapman               12
# Steven Spielberg          10
# David Dhawan               9
# Johnnie To                 8
# Name: count, dtype: int64

# %% [markdown]
# ### Q7. show all the records where type is movie and genre is comedies or country is united kingdom

# %%
data.head()
# Out:
#   show_id     type                                      title        director  \
# 0      s1  TV Show                                         3%             NaN
# 1     s10    Movie                                       1920    Vikram Bhatt
# 2    s100    Movie                                 3 Heroines  Iman Brotoseno
# 3   s1000    Movie  Blue Mountain State: The Rise of Thadland    Lev L. Spiro
# 4   s1001  TV Show                             Blue Planet II             NaN
#
#                                                 cast         country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...          Brazil
# 1  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...           India
# 2  Reza Rahadian, Bunga Citra Lestari, Tara Basro...       Indonesia
# 3  Alan Ritchson, Darin Brooks, James Cade, Rob R...   United States
# 4                                 David Attenborough  United Kingdom
#
#   date_added  release_year rating  duration  \
# ...

# %%
#using filtering we get the result
data[(data["type"]=="Movie")&(data["genres"]=="Comedies")|(data["country"]=="United Kingdom")]
# Out:
#      show_id     type                                      title  \
# 3      s1000    Movie  Blue Mountain State: The Rise of Thadland
# 4      s1001  TV Show                             Blue Planet II
# 25     s1020    Movie          Bobby Robson: More Than a Manager
# 56     s1049  TV Show                                 Borderline
# 71     s1062  TV Show                          Botched Up Bodies
# ...      ...      ...                                        ...
# 7702    s922    Movie                     Bill Hicks: Relentless
# 7703    s923    Movie                    Bill Hicks: Revelations
# 7721     s94    Movie                          27: Gone Too Soon
# 7733    s950  TV Show                         Black Earth Rising
# 7740    s957  TV Show                               Black Mirror
#
#                            director  \
# 3                      Lev L. Spiro
# 4                               NaN
# 25    Gabriel Clarke, Torquil Jones
# ...

# %% [markdown]
# ### Q8. in how many movies/shows Tom cruise was cast

# %%
data.head()
# Out:
#   show_id     type                                      title        director  \
# 0      s1  TV Show                                         3%             NaN
# 1     s10    Movie                                       1920    Vikram Bhatt
# 2    s100    Movie                                 3 Heroines  Iman Brotoseno
# 3   s1000    Movie  Blue Mountain State: The Rise of Thadland    Lev L. Spiro
# 4   s1001  TV Show                             Blue Planet II             NaN
#
#                                                 cast         country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...          Brazil
# 1  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...           India
# 2  Reza Rahadian, Bunga Citra Lestari, Tara Basro...       Indonesia
# 3  Alan Ritchson, Darin Brooks, James Cade, Rob R...   United States
# 4                                 David Attenborough  United Kingdom
#
#   date_added  release_year rating  duration  \
# ...

# %%
data[data["cast"]=="Tom Cruise"]#filtering
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, genres, description, date_n, year]
# Index: []

# %%
data["cast"].str.contains("Tom Cruise")#using command ".str.contains()"
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7782      NaN
# 7783    False
# 7784    False
# 7785    False
# 7786    False
# Name: cast, Length: 7787, dtype: object

# %%
data_new=data.dropna()#creating new dataframe by droping all null/na

# %%
data_new[data_new["cast"].str.contains("Tom Cruise")] #using command ".str.contains()" to get the result
# Out:
#      show_id   type     title              director  \
# 3180   s3861  Movie  Magnolia  Paul Thomas Anderson
# 4525   s5071  Movie  Rain Man        Barry Levinson
#
#                                                    cast        country  \
# 3180  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 4525  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#      date_added  release_year rating  duration                      genres  \
# 3180  01-Jan-20          1999      R       189  Dramas, Independent Movies
# 4525  01-Jul-19          1988      R       134      Classic Movies, Dramas
#
#                                             description     date_n    year
# 3180  Through chance, human action, past history and... 2020-01-01  2020.0
# 4525  A fast-talking yuppie is forced to slow down w... 2019-07-01  2019.0

# %% [markdown]
# ### Q9. what are the different ratings defined by netflix

# %%
data.head()
# Out:
#   show_id     type                                      title        director  \
# 0      s1  TV Show                                         3%             NaN
# 1     s10    Movie                                       1920    Vikram Bhatt
# 2    s100    Movie                                 3 Heroines  Iman Brotoseno
# 3   s1000    Movie  Blue Mountain State: The Rise of Thadland    Lev L. Spiro
# 4   s1001  TV Show                             Blue Planet II             NaN
#
#                                                 cast         country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...          Brazil
# 1  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...           India
# 2  Reza Rahadian, Bunga Citra Lestari, Tara Basro...       Indonesia
# 3  Alan Ritchson, Darin Brooks, James Cade, Rob R...   United States
# 4                                 David Attenborough  United Kingdom
#
#   date_added  release_year rating  duration  \
# ...

# %%
data["rating"].nunique() #getting the result by using ".nunique()"
# Out:
# 14

# %%
data.rating.nunique()
# Out:
# 14

# %%
data["rating"].unique() #getting the result by using ".unique()"
# Out:
# array(['TV-MA', 'TV-PG', 'R', 'TV-G', 'PG-13', 'TV-14', 'TV-Y', 'PG',
#        'TV-Y7', 'NR', 'G', 'TV-Y7-FV', nan, 'UR', 'NC-17'], dtype=object)

# %%
data.rating.unique()
# Out:
# array(['TV-MA', 'TV-PG', 'R', 'TV-G', 'PG-13', 'TV-14', 'TV-Y', 'PG',
#        'TV-Y7', 'NR', 'G', 'TV-Y7-FV', nan, 'UR', 'NC-17'], dtype=object)

# %% [markdown]
# ### Q9.1 how many movies got the TV-14 rating in canada

# %%
data[(data["type"]=="Movie")&(data["rating"]=="TV-14")&(data["country"]=="Canada")].shape #using command ".shape"
# Out:
# (11, 14)

# %% [markdown]
# ### Q9.2 how many tv show got r rating after year 2018?

# %%
data[(data["type"]=="TV Show")&(data["rating"]=="R")&(data["year"]>2018)].shape#by using commnad ".shape"
# Out:
# (1, 14)

# %% [markdown]
# ### Q10. What is the maximum duration of Movie/TV Show on netflix

# %%
data.head()
# Out:
#   show_id     type                                      title        director  \
# 0      s1  TV Show                                         3%             NaN
# 1     s10    Movie                                       1920    Vikram Bhatt
# 2    s100    Movie                                 3 Heroines  Iman Brotoseno
# 3   s1000    Movie  Blue Mountain State: The Rise of Thadland    Lev L. Spiro
# 4   s1001  TV Show                             Blue Planet II             NaN
#
#                                                 cast         country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...          Brazil
# 1  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...           India
# 2  Reza Rahadian, Bunga Citra Lestari, Tara Basro...       Indonesia
# 3  Alan Ritchson, Darin Brooks, James Cade, Rob R...   United States
# 4                                 David Attenborough  United Kingdom
#
#   date_added  release_year rating  duration  \
# ...

# %%
data[(data["type"]=="Movie")|(data["type"]=="TV Show")].duration.max()
# Out:
# 312

# %%
data.duration.unique()
# Out:
# array([  4, 143, 124,  90,   1,  94, 112, 129,  85, 108,  60, 164,  97,
#         47,  99,  83, 168, 116,  53, 106, 130, 161, 111,   6,  26,  92,
#         93, 102,  89, 123,  86,  88, 126, 117,  91,   3,  79,   2,  96,
#         70,  87,  74, 139,  84, 100,  80, 105, 114,  63,  51,   5,  81,
#         77,  61, 110, 103, 118,  95, 133, 120, 155,  14,  73,  98, 119,
#         76, 104, 148,  78, 128, 122, 177, 135, 127, 151, 125, 101,  11,
#         22,   9,  46, 142, 131, 113,  67,  82, 145, 141,  75, 107, 156,
#        132, 166, 121, 115,  71,  62,  25, 146,  66,  55,  65, 137,  59,
#         56,  34, 158, 109,  69, 172,   7,   8,  57,  28,  13,  52,  45,
#         12, 176,  40,  58, 153,  10,  64, 149,  43,  68, 140,  50,  29,
#        136, 157,  23, 165, 185, 174, 154, 134, 200, 144,  21, 169,  27,
#         42, 162, 170,  48, 196,  49, 163,  20,  54, 150,  33,  72, 181,
#        204,  44,  32,  35, 167,  30,  16, 138, 179, 193,  24, 147, 214,
# ...

# %%
data.duration.max()
# Out:
# 312

# %% [markdown]
# ### Q11. which individual country has the highest nos. of TV show

# %%
data.head()
# Out:
#   show_id     type                                      title        director  \
# 0      s1  TV Show                                         3%             NaN
# 1     s10    Movie                                       1920    Vikram Bhatt
# 2    s100    Movie                                 3 Heroines  Iman Brotoseno
# 3   s1000    Movie  Blue Mountain State: The Rise of Thadland    Lev L. Spiro
# 4   s1001  TV Show                             Blue Planet II             NaN
#
#                                                 cast         country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...          Brazil
# 1  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...           India
# 2  Reza Rahadian, Bunga Citra Lestari, Tara Basro...       Indonesia
# 3  Alan Ritchson, Darin Brooks, James Cade, Rob R...   United States
# 4                                 David Attenborough  United Kingdom
#
#   date_added  release_year rating  duration  \
# ...

# %%
data[data["type"]=="TV Show"].country.value_counts().head(1) #getting the answer
# Out:
# country
# United States    705
# Name: count, dtype: int64

# %% [markdown]
# ### Q12. how can we sort the dataset by year?

# %%
data.sort_values(by="year", ascending=False).head()#using command ".sort_values(by="", ascending=True/False)"
# Out:
#      show_id     type                        title             director  \
# 869    s1781  TV Show               Disenchantment                  NaN
# 750    s1674    Movie                  Death of Me  Darren Lynn Bousman
# 7301   s7570    Movie  What Would Sophia Loren Do?        Ross Kauffman
# 7281   s7552    Movie    What Happened to Mr. Cha?         Kim Dong-kyu
# 2967    s367    Movie                    Al acecho  Francisco D'Eufemia
#
#                                                    cast  \
# 869   Abbi Jacobson, Eric André, Nat Faxon, John DiM...
# 750   Maggie Q, Luke Hemsworth, Alex Essoe, Ingkarat...
# 7301        Nancy "Vincenza Careri" Kulik, Sophia Loren
# 7281           Cha In-pyo, Cho Dal-hwan, Song Jae-ryong
# 2967  Rodrigo de la Serna, Belen Blanco, Walter Jako...
#
#                       country date_added  release_year rating  duration  \
# 869             United States  15-Jan-21          2021  TV-14         3
# ...

# %% [markdown]
# ### Q13. find all the instances where:
# type is movie and generes is drama
#
# or
#
# type is tv show and genres is kids'tv

# %%
data.head()
# Out:
#   show_id     type                                      title        director  \
# 0      s1  TV Show                                         3%             NaN
# 1     s10    Movie                                       1920    Vikram Bhatt
# 2    s100    Movie                                 3 Heroines  Iman Brotoseno
# 3   s1000    Movie  Blue Mountain State: The Rise of Thadland    Lev L. Spiro
# 4   s1001  TV Show                             Blue Planet II             NaN
#
#                                                 cast         country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...          Brazil
# 1  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...           India
# 2  Reza Rahadian, Bunga Citra Lestari, Tara Basro...       Indonesia
# 3  Alan Ritchson, Darin Brooks, James Cade, Rob R...   United States
# 4                                 David Attenborough  United Kingdom
#
#   date_added  release_year rating  duration  \
# ...

# %%
data[(data["type"]=="Movie")&(data["genres"].str.contains("Dramas"))]
# Out:
#      show_id   type                      title                    director  \
# 2       s100  Movie                 3 Heroines              Iman Brotoseno
# 7      s1004  Movie             Blue Valentine            Derek Cianfrance
# 13      s101  Movie                   3 Idiots             Rajkumar Hirani
# 21     s1017  Movie                      Bobby                  Raj Kapoor
# 22     s1018  Movie               Bobby Jasoos                Samar Shaikh
# ...      ...    ...                        ...                         ...
# 7778    s991  Movie            Blood Will Tell  Miguel Cohan, Miguel Cohan
# 7781    s994  Movie                       Blow                   Ted Demme
# 7784    s997  Movie  Blue Is the Warmest Color         Abdellatif Kechiche
# 7785    s998  Movie               Blue Jasmine                 Woody Allen
# 7786    s999  Movie                   Blue Jay                Alex Lehmann
#
#                                                    cast  \
# ...

# %%
data[(data["type"]=="TV Show")&(data["genres"].str.contains("Kids' TV"))]
# Out:
#      show_id     type                     title director  \
# 15     s1011  TV Show             Bo on the Go!      NaN
# 51     s1044  TV Show                     Booba      NaN
# 52     s1045  TV Show                 Bookmarks      NaN
# 72     s1063  TV Show    Bottersnikes & Gumbles      NaN
# 86     s1076  TV Show                Brainchild      NaN
# ...      ...      ...                       ...      ...
# 7644    s870  TV Show  Beyblade Burst Evolution      NaN
# 7645    s871  TV Show       Beyblade Burst Rise      NaN
# 7646    s872  TV Show      Beyblade Burst Turbo      NaN
# 7647    s873  TV Show    Beyblade: Metal Fusion      NaN
# 7678    s900  TV Show       Big Bad Beetleborgs      NaN
#
#                                                    cast  \
# 15      Catherine O'Connor, Andrew Sabiston, Jim Fowler
# 51                                          Roman Karev
# 52                                          Marley Dias
# ...

# %%
data["genres"]
# Out:
# 0       International TV Shows, TV Dramas, TV Sci-Fi &...
# 1          Horror Movies, International Movies, Thrillers
# 2             Dramas, International Movies, Sports Movies
# 3                                                Comedies
# 4       British TV Shows, Docuseries, Science & Nature TV
#                               ...
# 7782                   International TV Shows, Reality TV
# 7783                 Anime Series, International TV Shows
# 7784     Dramas, Independent Movies, International Movies
# 7785                 Comedies, Dramas, Independent Movies
# 7786          Dramas, Independent Movies, Romantic Movies
# Name: genres, Length: 7787, dtype: object

# %%
data.genres.unique()
# Out:
# array(['International TV Shows, TV Dramas, TV Sci-Fi & Fantasy',
#        'Horror Movies, International Movies, Thrillers',
#        'Dramas, International Movies, Sports Movies', 'Comedies',
#        'British TV Shows, Docuseries, Science & Nature TV',
#        'Independent Movies, Thrillers', 'Action & Adventure, Comedies',
#        'Dramas, Independent Movies, Romantic Movies',
#        'Comedies, International Movies, Romantic Movies', 'Documentaries',
#        'Anime Series, International TV Shows',
#        'Documentaries, International Movies, Music & Musicals',
#        'Music & Musicals, Stand-Up Comedy',
#        'Comedies, Dramas, International Movies', 'Stand-Up Comedy',
#        "Kids' TV", 'TV Shows', 'Children & Family Movies',
#        'Children & Family Movies, Comedies',
#        'Classic Movies, Dramas, International Movies', 'Docuseries',
#        'Documentaries, Faith & Spirituality',
#        'Documentaries, International Movies, Sports Movies',
# ...

# %%
data[(data["type"]=="Movie")&(data["genres"].str.contains("Dramas"))|(data["type"]=="TV Show")&(data["genres"].str.contains("Kids' TV"))]
# Out:
#      show_id     type                      title                    director  \
# 2       s100    Movie                 3 Heroines              Iman Brotoseno
# 7      s1004    Movie             Blue Valentine            Derek Cianfrance
# 13      s101    Movie                   3 Idiots             Rajkumar Hirani
# 15     s1011  TV Show              Bo on the Go!                         NaN
# 21     s1017    Movie                      Bobby                  Raj Kapoor
# ...      ...      ...                        ...                         ...
# 7778    s991    Movie            Blood Will Tell  Miguel Cohan, Miguel Cohan
# 7781    s994    Movie                       Blow                   Ted Demme
# 7784    s997    Movie  Blue Is the Warmest Color         Abdellatif Kechiche
# 7785    s998    Movie               Blue Jasmine                 Woody Allen
# 7786    s999    Movie                   Blue Jay                Alex Lehmann
#
# ...
